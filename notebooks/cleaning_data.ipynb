# %% [markdown]
# # Criando o dataset 'online_retail':
#
# O banco de dados foi extraído em formato xlsx do [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/dataset/352/online+retail).
#
# Com o pandas, criei um database em POSTGRESQL a partir do arquivo 'Online Retail.xlsx'.

# %%
# %run ../src/create_dataset.py
# Out:
#    invoice_no stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5      536365      22752         SET 7 BABUSHKA NESTING BOXES         2
# 6      536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7      536366      22633               HAND WARMER UNION JACK         6
# 8      536366      22632            HAND WARMER RED POLKA DOT         6
# 9      536367      84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10     536367      22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11     536367      22748            POPPY'S PLAYHOUSE KITCHEN         6
# 12     536367      22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13     536367      22310              IVORY KNITTED MUG COSY          6
# 14     536367      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15     536367      22623        BOX OF VINTAGE JIGSAW BLOCKS          3
# 16     536367      22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 17     536367      21754             HOME BUILDING BLOCK WORD         3
# 18     536367      21755             LOVE BUILDING BLOCK WORD         3
# 19     536367      21777          RECIPE BOX WITH METAL HEART         4
#
#           invoice_date  unit_price  customer_id         country
# 0  2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1  2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2  2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3  2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4  2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 5  2010-12-01 08:26:00        7.65      17850.0  United Kingdom
# 6  2010-12-01 08:26:00        4.25      17850.0  United Kingdom
# 7  2010-12-01 08:28:00        1.85      17850.0  United Kingdom
# 8  2010-12-01 08:28:00        1.85      17850.0  United Kingdom
# 9  2010-12-01 08:34:00        1.69      13047.0  United Kingdom
# 10 2010-12-01 08:34:00        2.10      13047.0  United Kingdom
# 11 2010-12-01 08:34:00        2.10      13047.0  United Kingdom
# 12 2010-12-01 08:34:00        3.75      13047.0  United Kingdom
# 13 2010-12-01 08:34:00        1.65      13047.0  United Kingdom
# 14 2010-12-01 08:34:00        4.25      13047.0  United Kingdom
# 15 2010-12-01 08:34:00        4.95      13047.0  United Kingdom
# 16 2010-12-01 08:34:00        9.95      13047.0  United Kingdom
# 17 2010-12-01 08:34:00        5.95      13047.0  United Kingdom
# 18 2010-12-01 08:34:00        5.95      13047.0  United Kingdom
# 19 2010-12-01 08:34:00        7.95      13047.0  United Kingdom

# %% [markdown]
# # Limpando o dataset 'online_retail':
#
# Em uma análise preliminar do dataset, foi observado valores NULL e outros erros que poderiam prejudicar a análise dos dados. Para isso, usei POSTGRESQL para limpar o banco de dados usando a seguinte querry:

# %% [markdown]
# ```postgresql
# CREATE TABLE IF NOT EXISTS online_retail_cleaned AS
#
# SELECT
#     -- Invoice: apenas os que começam com dígito
#     invoice_no,
#
#     -- StockCode: remove letras e mantém apenas códigos numéricos
#     regexp_replace(stock_code, '[[:alpha:]]', '', 'g') AS stock_code_cleaned,
#
#     -- Description: lowercase, trim e normaliza espaços
#     lower(trim(regexp_replace(description, '[\s,]+', ' ', 'g'))) AS description_cleaned,
#
#     -- Quantity: valor absoluto
#     ABS(quantity) AS quantity_cleaned,
#
#     -- InvoiceDate: sem alteração necessária
#     invoice_date,
#
#     -- UnitPrice: apenas valores positivos
#     ABS(unit_price) AS unit_price_cleaned,
#
#     -- CustomerID: mantido (filtrado no WHERE)
#     customer_id,
#
#     -- Country: lowercase + trim
#     trim(lower(country)) AS country_cleaned
#
# FROM online_retail
# WHERE
#     -- invoice começa com dígito
#     invoice_no ~ '^[[:digit:]]'
#
#     -- customer_id válido
#     AND customer_id IS NOT NULL
#
#     -- unit_price positivo
#     AND unit_price > 0
#
#     -- stock_code limpo com exatamente 5 dígitos
#     AND length(regexp_replace(stock_code, '[[:alpha:]]', '', 'g')) = 5
#
#     -- retirar pedidos cancelados (stock_code inicia com 'c')
#     AND lower(stock_code) NOT LIKE 'c%';

# %% [markdown]
# # Criando o dataset 'online_retail_cleaned':
#
# Com o pandas, criei um database em POSTGRESQL com as modificações anteriores a partir do arquivo 'Online Retail.xlsx'.

# %%
# %run ../src/create_cleaned_dataset.py
# Out:
#    invoice_no stock_code_cleaned                  description_cleaned  \
# 0      536783              84692          box of 24 cocktail parasols
# 1      536783              84347  rotating silver angels t-light hldr
# 2      536783              71459       hanging jam jar t-light holder
# 3      536783              48194                       doormat hearts
# 4      536783              48184                 doormat english rose
# 5      536783              35001                 hand open shape gold
# 6      536783              22752         set 7 babushka nesting boxes
# 7      536783              22659              lunch box i love london
# 8      536783              22630                 dolly girl lunch box
# 9      536783              22629                   spaceboy lunch box
# 10     536783              22585            pack of 6 birdy gift tags
# 11     536783              22536           magic drawing slate purdey
# 12     536783              22534         magic drawing slate spaceboy
# 13     536783              22533      magic drawing slate bake a cake
# 14     536784              85116      black candelabra t-light holder
# 15     536784              84952       black love bird t-light holder
# 16     536784              84347  rotating silver angels t-light hldr
# 17     536784              71459       hanging jam jar t-light holder
# 18     536784              48187                  doormat new england
# 19     536784              22752         set 7 babushka nesting boxes
#
#     quantity_cleaned        invoice_date  unit_price_cleaned  customer_id  \
# 0                 50 2010-12-02 15:19:00                0.32      15061.0
# 1                120 2010-12-02 15:19:00                1.88      15061.0
# 2                144 2010-12-02 15:19:00                0.72      15061.0
# 3                 70 2010-12-02 15:19:00                6.75      15061.0
# 4                 30 2010-12-02 15:19:00                6.75      15061.0
# 5                 42 2010-12-02 15:19:00                3.39      15061.0
# 6                 96 2010-12-02 15:19:00                7.65      15061.0
# 7                 64 2010-12-02 15:19:00                1.65      15061.0
# 8                 64 2010-12-02 15:19:00                1.65      15061.0
# 9                 64 2010-12-02 15:19:00                1.65      15061.0
# 10                72 2010-12-02 15:19:00                1.25      15061.0
# 11                48 2010-12-02 15:19:00                0.36      15061.0
# 12                96 2010-12-02 15:19:00                0.36      15061.0
# 13                24 2010-12-02 15:19:00                0.36      15061.0
# 14                24 2010-12-02 15:20:00                1.25      15061.0
# 15                12 2010-12-02 15:20:00                1.25      15061.0
# 16               240 2010-12-02 15:20:00                1.88      15061.0
# 17                96 2010-12-02 15:20:00                0.72      15061.0
# 18                30 2010-12-02 15:20:00                6.75      15061.0
# 19                72 2010-12-02 15:20:00                7.65      15061.0
#
#    country_cleaned
# 0   united kingdom
# 1   united kingdom
# 2   united kingdom
# 3   united kingdom
# 4   united kingdom
# 5   united kingdom
# 6   united kingdom
# 7   united kingdom
# 8   united kingdom
# 9   united kingdom
# 10  united kingdom
# 11  united kingdom
# 12  united kingdom
# 13  united kingdom
# 14  united kingdom
# 15  united kingdom
# 16  united kingdom
# 17  united kingdom
# 18  united kingdom
# 19  united kingdom
